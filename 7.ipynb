# %%
import pandas as pd
import numpy as np
# import matplot
import matplotlib.pyplot as plt
# imported all files

# %%
# get the data from the URL
data_frame = pd.read_csv('https://cocl.us/datascience_survey_data')

# %%
# df.head()
df.sort_values('Unnamed: 0')
# show values by sort of first column
# Out:
#                    Unnamed: 0  Very interested  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332                  729
# 1  Data Analysis / Statistics             1688                  444
# 2             Data Journalism              429                 1081
# 3          Data Visualization             1340                  734
# 4               Deep Learning             1263                  770
# 5            Machine Learning             1629                  477
#
#    Not interested
# 0             127
# 1              60
# 2             610
# 3             102
# 4             136
# 5              74

# %%
# sort in descending
df = data_frame.sort_values(by='Very interested', ascending=False)
x = df[df.columns[0]].to_numpy()
y_axis = df[df.columns[1:4]].to_numpy()
df.head()
# Out:
#                    Unnamed: 0  Very interested  Somewhat interested  \
# 1  Data Analysis / Statistics             1688                  444
# 5            Machine Learning             1629                  477
# 3          Data Visualization             1340                  734
# 0   Big Data (Spark / Hadoop)             1332                  729
# 4               Deep Learning             1263                  770
#
#    Not interested
# 1              60
# 5              74
# 3             102
# 0             127
# 4             136

# %%
# plotting the graph using matplotlib
ax = df.plot(kind='bar', figsize=(20, 8), width=0.8, color=['#5cb85c', '#5bc0de', '#d9534f'], fontsize=14)
ax.set_title('Interest in Data Science Areas')
ax.set_facecolor('white')
ax.legend(fontsize=14, facecolor='white')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
x_axis = np.arange(6)

# Show plot
plt.xticks(x_axis, x)
plt.show()
