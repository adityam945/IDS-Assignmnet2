# %% [markdown]
# # Problem 6
# friendship problem

# %%
import pandas as pd
import numpy as np
# load the data
df = pd.read_csv("./data/p6/Friendship.csv", index_col=0)

# %%
# visualize the df
df
# Out:
#                  Hyunjin Yi Mike Zahorec Cole McGuire Marcelo Paesani  \
# Hyunjin Yi              1.0            1            0               0
# Mike Zahorec            1.0            1            0               0
# Cole McGuire            0.0            0            1               0
# Marcelo Paesani         NaN          NaN          NaN               1
# Brady Henderson         0.0            0            0               0
# ...                     ...          ...          ...             ...
# Austin Miller           0.0            0            1               0
# AIdan Mahoney           0.0            0            0               0
# Frecks Bertrand         NaN          NaN          NaN             NaN
# Abhishek Pavshe         NaN          NaN          NaN             NaN
# NaN                     3.0            8            5               3
#
#                 Brady Henderson Jacquelyn Nogueras  Caitlyn Jessee  Zhixi Lin  \
# ...

# %%
# df = df.sort_index()
# df = df.sort_index(axis=1)

valid_column_names = set(df.index)
df = df.reset_index().drop_duplicates(subset='index', keep='first').set_index('index')

# %%
df
# Out:
#                  Hyunjin Yi Mike Zahorec Cole McGuire Marcelo Paesani  \
# index
# Hyunjin Yi              1.0            1            0               0
# Mike Zahorec            1.0            1            0               0
# Cole McGuire            0.0            0            1               0
# Marcelo Paesani         NaN          NaN          NaN               1
# Brady Henderson         0.0            0            0               0
# ...                     ...          ...          ...             ...
# Austin Miller           0.0            0            1               0
# AIdan Mahoney           0.0            0            0               0
# Frecks Bertrand         NaN          NaN          NaN             NaN
# Abhishek Pavshe         NaN          NaN          NaN             NaN
# NaN                     3.0            8            5               3
#
#                 Brady Henderson Jacquelyn Nogueras  Caitlyn Jessee  Zhixi Lin  \
# index
# ...

# %%
df.index
# Out:
# Index([                     'Hyunjin Yi',                    'Mike Zahorec',
#                           'Cole McGuire',                 'Marcelo Paesani',
#                        'Brady Henderson',              'Jacquelyn Nogueras',
#                         'Caitlyn Jessee',                       'Zhixi Lin',
#                        'Sabrina Callejo',         'AkhilRaj Tirumalasetty ',
#                             'Jack Moran',                   'Candies Woods',
#                           'Pooja Mhetre',                  'Jason St. John',
#                         'Ibrahim Afridi',                    'Holly Jordan',
#                            'Xiaoxia Che',                      'Aojie Yang',
#                        'Andrew Franklin',                     'Ian Cleaver',
#                     'Ayoola Oguntoyinbo',                  'Hannah Housand',
#                    'Yasaswi Akash Gunda',                  'Varun Totakura',
# ...

# %%
# df = df.drop(index="nan")
df = df.drop(87)

# df = df.drop(df.index[-1])
df = df.drop(columns=[col for col in df if col not in valid_column_names])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [160], line 2
#       1 # df = df.drop(index="nan")
# ----> 2 df = df.drop(87)
#       4 # df = df.drop(df.index[-1])
#       5 df = df.drop(columns=[col for col in df if col not in valid_column_names])
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:5388, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df
# Out:
#                      Hyunjin Yi Mike Zahorec Cole McGuire Marcelo Paesani  \
# index
# Hyunjin Yi                  1.0            1            0               0
# Mike Zahorec                1.0            1            0               0
# Cole McGuire                0.0            0            1               0
# Marcelo Paesani             NaN          NaN          NaN               1
# Brady Henderson             0.0            0            0               0
# ...                         ...          ...          ...             ...
# Keerthi Reddy Vudem         0.0            0            0               0
# Austin Miller               0.0            0            1               0
# AIdan Mahoney               0.0            0            0               0
# Frecks Bertrand             NaN          NaN          NaN             NaN
# Abhishek Pavshe             NaN          NaN          NaN             NaN
#
# ...

# %%
df = df.fillna(0)

# %%
df
# Out:
#                                 AIdan Mahoney  Abhiram Vissamsetty   \
# index
# AIdan Mahoney                             1.0                   0.0
# Abhiram Vissamsetty                       0.0                   1.0
# Abhishek Pavshe                           0.0                   0.0
# Abhishek Prakash                          0.0                   0.0
# Aditya Madhusudhan                        0.0                   1.0
# ...                                       ...                   ...
# Yasaswi Akash Gunda                       0.0                   0.0
# Yunzheng Lyu                              0.0                   0.0
# Zhixi Lin                                 0.0                   0.0
# puneeth reddy motukuru Damodar            0.0                   0.0
# sparsh khare                              0.0                   0.0
#
#                                 Abhishek Pavshe  Abhishek Prakash  \
# index
# AIdan Mahoney                               2.0               0.0
# ...

# %% [markdown]
# we still dont have the balance

# %%
current_cols = set(df.columns)

# %%
valid_column_names - current_cols
# Out:
# {'Juan R Reza', 'Mauricio Espinoza', nan}

# %%
cols = set(df.columns)
valid_columns - cols
# Out:
# {nan}
